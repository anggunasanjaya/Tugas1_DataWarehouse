# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn')

# %%
iris = pd.read_csv('iris.csv')

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris.head()
# Out:
#    samsung  apple  vivo  oppo species
# 0      5.0    3.0   7.0   2.0      hp
# 1      6.0    4.0   6.0   8.0      hp
# 2      7.0    5.0   5.0   2.0      hp
# 3      8.0    6.0   4.0   1.0      hp
# 4      9.0    7.0   5.0   5.0      hp

# %%
iris.plot(x='samsung', y='apple')
# Out:
# <AxesSubplot:xlabel='samsung'>
